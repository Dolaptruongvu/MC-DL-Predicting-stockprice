# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Đọc dữ liệu từ tập tin CSV với các tùy chọn
df = pd.read_csv('SONY.csv', header=0, parse_dates=[0], index_col=0)

# In ra 5 dòng đầu tiên của DataFrame
print(df.head())
# Out:
#             Price
# Date
# 2018-01-02  45.79
# 2018-01-03  46.30
# 2018-01-04  47.25
# 2018-01-05  48.70
# 2018-01-08  49.00

# %%
# 2.  chia train test validate theo tỉ lệ 7:3
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
# Split the data into training, testing
train_size = int(0.7 * len(df))
test_size = int(0.3 * len(df))

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %%
# Finding best model based on train data
y_train = np.array(train_data['Price'])


from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)


model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3718.384, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3725.848, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3724.646, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3724.950, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3725.424, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3725.121, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3725.440, Time=0.12 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=3720.553, Time=0.64 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=3709.398, Time=0.40 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3725.892, Time=0.15 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=3711.234, Time=0.52 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=3706.411, Time=0.67 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=3723.352, Time=0.18 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=3713.200, Time=0.79 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=3708.388, Time=0.85 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=3724.310, Time=0.34 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=3709.482, Time=0.95 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=3706.048, Time=0.48 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=3723.236, Time=0.13 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=3709.257, Time=0.30 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=3712.987, Time=0.57 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=3708.031, Time=0.67 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3724.372, Time=0.21 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=3723.944, Time=0.21 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=3711.076, Time=0.37 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=3709.107, Time=0.69 sec
#
# Best model:  ARIMA(2,1,4)(0,0,0)[0]
# Total fit time: 9.781 seconds
# ARIMA(order=(2, 1, 4), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
# dermine y test and y predict for comparision
y_test = np.array(test_data['Price'])
y_pred = model.predict(n_periods=len(y_test))

# %%
# Determine the last index and create the 30 days data range
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Need to change the array ( 30 days ) to column for prediction
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [104.68542636 104.43406756 103.4124985  102.70985434 102.9998989
#  103.99362206 104.72696378 104.49602262 103.53259977 102.77184611
#  102.94462763 103.87546563 104.66035034 104.54462132 103.64848022
#  102.84273003 102.90266876 103.76217531 104.58555102 104.57999392
#  103.75888377 102.92108706 102.87380882 103.65493717 104.50399532
#  104.602434   103.86269626 103.00548221 102.85767742 103.55479189]

# %%
# Vẽ biểu đồ
plt.figure(figsize=(10, 6)) # Set the figure size
plt.plot(x_next_30_days, y_next_30_days, marker='o', color='b', label='Predicted Next 30 Days')

# Đặt tiêu đề và nhãn
plt.title('Predicted Values for the Next 30 Days')
plt.xlabel('Date')
plt.ylabel('Predicted Value')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error
# 7. Đánh giá độ chính xác test bằng RMSE, MAE , MAPE
# RMSE
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Testing RMSE:', test_rmse)
# MAPE
test_mape = mean_absolute_percentage_error(y_test,y_pred)
print('Testing MAPE:', test_mape)
# MAE
test_mae = mean_absolute_error(y_test,y_pred)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 19.60268349577704
# Testing MAPE: 0.21904269175648028
# Testing MAE: 17.799683798327745

# %%
# 8. Tính RMSE
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Testing RMSE:', test_rmse)
# MAPE
test_mape = mean_absolute_percentage_error(y_test,y_pred)
print('Testing MAPE:', test_mape)
# MAE
test_mae = mean_absolute_error(y_test,y_pred)
print('Testing MAE:', test_mae)

# 9.Vẽ hình
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()
# Out:
# Testing RMSE: 19.60268349577704
# Testing MAPE: 0.21904269175648028
# Testing MAE: 17.799683798327745

# %%
test_data.index
# Out:
# RangeIndex(start=1046, stop=1494, step=1)
